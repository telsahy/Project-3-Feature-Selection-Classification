# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFE
from sklearn import linear_model
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, SelectFromModel, f_regression
import seaborn as sns
# %matplotlib inline

# %%
df_train_data = pd.read_csv('madelon_train.data.csv', delimiter=' ', header=None).drop(500, axis=1)

# %%
df_train_labels = pd.read_csv('madelon_train.labels.csv', delimiter=' ', header=None)

# %%
train_data_10pct_1 = df_train_data.sample(200)

# %%
y = df_train_labels[0]

# %%
y_10pct_1 = y.sample(2000)

# %%
df_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Columns: 500 entries, 0 to 499
# dtypes: int64(500)
# memory usage: 7.6 MB

# %%
corr_df = df_train_data.corr()

# %%
corrs = list(corr_df[corr_df[corr_df.abs() >.5].count() > 1].index)

# %% [markdown]
# ### Creating DataFrame with 20 important/redundant features and eliminating noise

# %%
imp_feat_df = df_train_data.iloc[:, corrs]

# %%
imp_feat_df.head()
# Out:
#    28   48   64   105  128  153  241  281  318  336  338  378  433  442  451  \
# 0  459  440  648  181  452  575  434  517  414  658  628  419  533  568  463
# 1  475  499  488  431  473  404  551  435  469  469  528  526  442  463  474
# 2  491  460  485  593  487  585  474  535  506  465  431  464  569  503  481
# 3  472  529  415  698  493  591  569  526  458  398  377  553  565  447  472
# 4  472  429  387  451  475  448  538  456  462  385  509  424  462  536  472
#
#    453  455  472  475  493
# 0  471  630  515  401  485
# 1  311  582  465  549  338
# 2  606  424  485  454  650
# 3  545  456  457  602  572
# 4  426  465  500  560  435

# %% [markdown]
# ## PCA To Determine 5 Informative Features

# %%
pca = PCA()
pca.fit(imp_feat_df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[ -5.87306645e-03,  -5.16164173e-02,   1.42546240e-01,
#          -4.92877807e-01,  -4.19480286e-02,  -2.64630149e-01,
#          -2.16425901e-02,  -1.39235190e-01,  -1.75009144e-02,
#           1.67681641e-01,   3.16193410e-01,  -6.92681560e-02,
#          -1.85946601e-01,   1.14164905e-02,  -3.45904902e-03,
#          -4.20574825e-01,   2.69913828e-01,   4.77492099e-03,
#          -3.14327408e-02,  -4.73015873e-01],
#        [ -2.59324518e-02,  -5.01181081e-03,   3.59004740e-01,
#          -3.12513313e-01,  -2.67076638e-02,   1.59023574e-01,
#          -2.39900552e-01,   8.41592279e-02,  -8.24866956e-02,
#           4.19310595e-01,   2.35066553e-01,  -7.10439026e-03,
#           1.13332867e-01,   2.52673689e-01,  -1.64750661e-02,
#           3.25234665e-01,   4.67359261e-02,   1.15450142e-01,
#          -3.33887543e-01,   3.66678554e-01],
#        [ -3.13219356e-02,  -2.12317310e-02,  -2.33217885e-01,
#           8.44949560e-02,   7.17856631e-03,  -4.23922878e-01,
#          -5.60471238e-02,  -2.19769085e-01,  -9.95741518e-02,
#          -2.74263111e-01,   3.05687975e-01,  -2.77594390e-02,
#          -2.96910449e-01,   5.06205975e-01,  -1.99003985e-02,
#           1.09951605e-01,  -3.05916967e-01,   2.30481981e-01,
#          -8.14267235e-02,   1.27523255e-01],
#        [  6.99511009e-02,   3.21067341e-01,   2.44752863e-01,
#           5.03956032e-01,   4.20945008e-02,  -2.76384862e-01,
#          -1.48786408e-01,  -1.40230000e-01,   2.20523010e-01,
#           2.86831735e-01,   1.20770489e-01,   4.34783759e-01,
#          -1.92360681e-01,  -1.78736030e-01,   4.43408049e-02,
#          -3.91318597e-02,   3.94834016e-02,  -8.10402984e-02,
#          -2.04312572e-01,  -3.66414732e-02],
#        [ -1.57372445e-01,   3.75468499e-01,   1.16765842e-02,
#          -5.11311040e-02,  -4.44666439e-03,   1.01723799e-01,
#           2.53382444e-01,   5.09796800e-02,  -4.99450045e-01,
#           4.03927901e-03,   4.23167934e-02,   5.08035473e-01,
#           6.88409530e-02,   2.35113830e-01,  -9.84557324e-02,
#          -4.79264535e-03,   2.06994712e-01,   1.05663983e-01,
#           3.47984365e-01,  -1.18818935e-02],
#        [  2.35868624e-03,  -1.62352434e-02,   3.47590799e-02,
#          -5.00527979e-03,  -3.03813366e-03,  -3.25996334e-02,
#           1.27072168e-03,   1.81413790e-02,   2.60587575e-02,
#          -2.76091692e-03,   8.44785644e-03,  -6.23765818e-03,
#          -3.38108957e-03,   6.16942769e-03,   2.49707276e-03,
#          -7.23199223e-01,   1.58162550e-02,  -1.43333876e-02,
#           7.36360838e-02,   6.83628000e-01],
#        [  1.79119017e-02,   1.49491829e-01,  -1.48384967e-01,
#          -5.37464619e-01,   1.95783001e-02,  -3.96065416e-01,
#          -2.35399168e-03,  -4.88306730e-02,   9.02761391e-02,
#          -1.23814818e-01,  -1.50333977e-01,   2.42539431e-01,
#          -1.06272571e-01,  -4.54366725e-01,   1.26554654e-02,
#           2.95971754e-01,  -2.41202424e-02,  -4.55925612e-02,
#           6.69651535e-02,   2.98749312e-01],
#        [ -1.00021574e-02,  -4.19417774e-02,  -3.73479989e-01,
#          -1.54477732e-03,   1.89547362e-03,  -2.70111922e-01,
#           4.12548935e-02,   4.96512864e-02,  -2.08742922e-02,
#           7.23075334e-01,  -3.98983716e-01,  -7.20859524e-02,
#           2.99857763e-02,   1.96844489e-01,  -4.59848072e-03,
#          -4.00246727e-02,  -1.61351256e-01,   3.87510097e-02,
#           1.52039345e-01,  -4.40451995e-02],
#        [ -3.22948123e-04,  -1.75584245e-03,   4.88907735e-01,
#          -7.08304611e-03,   2.11996918e-03,  -3.70907234e-01,
#          -2.91625458e-02,   6.24964829e-02,  -2.79072929e-02,
#          -2.60537249e-01,  -6.19713061e-01,  -4.90848906e-02,
#           8.38471303e-02,   3.17157821e-01,   5.82516154e-04,
#          -1.67917561e-02,   1.88595061e-01,   1.01343243e-02,
#          -1.32983084e-01,  -4.70513153e-02],
#        [  3.56329546e-02,   1.55233050e-01,   1.51955393e-02,
#          -2.98178068e-01,   3.62655391e-02,   4.31732604e-01,
#          -8.07924461e-02,  -1.36166235e-01,   1.54308218e-01,
#          -5.60543912e-02,  -2.94537952e-01,   3.20886654e-01,
#          -2.48835515e-01,   1.74652606e-01,   2.43837772e-02,
#          -2.04181209e-01,  -4.97981909e-01,  -3.71429341e-02,
#          -2.15832264e-01,  -1.59325885e-01],
#        [  1.48480781e-02,   1.69637932e-02,  -5.18455793e-01,
#           1.18852159e-02,  -3.39129013e-03,   1.62932767e-01,
#          -8.12642815e-02,  -3.72984633e-02,   8.94988878e-02,
#          -6.72312165e-02,  -1.52566258e-01,   1.05445827e-01,
#          -1.62389995e-01,   1.52743026e-01,   9.64229644e-03,
#           2.81017726e-03,   6.39806988e-01,   7.47709431e-03,
#          -4.30499299e-01,   6.73403887e-02],
#        [ -1.50060416e-02,   6.88090411e-02,  -2.31050543e-01,
#          -4.33565788e-02,   5.94041044e-03,  -2.08387768e-01,
#          -1.15624020e-01,   1.27978355e-01,  -8.21298947e-02,
#          -1.14921566e-01,   1.17608481e-01,   2.01524540e-01,
#           7.36987141e-01,  -3.67855770e-02,  -6.43196584e-03,
#          -1.88792912e-01,  -1.97488856e-01,  -6.13165917e-03,
#          -3.89293556e-01,  -1.46271688e-01],
#        [  9.45492216e-02,   3.57761347e-02,  -4.08954063e-02,
#          -1.00198759e-01,   3.25448235e-02,   5.43525884e-03,
#          -2.21815618e-01,  -1.05549779e-02,   5.93429664e-01,
#          -6.19164991e-02,   1.36336604e-01,   1.54693465e-01,
#           2.57520834e-01,   3.97752370e-01,   5.96729675e-02,
#           7.75306286e-02,   1.34151338e-01,  -2.57104762e-01,
#           4.59302543e-01,   1.33854727e-03],
#        [  3.99221106e-02,  -1.86269996e-02,   6.42589054e-02,
#          -4.84858380e-02,   9.56539478e-03,  -4.33700099e-02,
#           8.57191271e-01,  -1.06762534e-01,   2.37842028e-01,
#           6.77209595e-02,   1.05337413e-01,   3.46663778e-03,
#           7.86630303e-02,   1.44531301e-01,   2.23664973e-02,
#           7.06015232e-02,  -2.61604351e-02,  -2.59620115e-01,
#          -2.52887198e-01,   8.10416579e-02],
#        [  1.33904010e-02,   3.59073552e-02,  -4.07191466e-02,
#          -1.59563742e-02,   7.21427678e-03,  -9.83342024e-02,
#           2.66507581e-02,   9.00516056e-01,   4.31962931e-02,
#          -5.06896959e-02,   1.21590504e-01,   5.26673263e-02,
#          -3.07567501e-01,   7.64909023e-02,   5.12272370e-03,
#          -2.67625300e-02,  -7.97201846e-02,  -1.94583937e-01,
#          -7.03402418e-02,  -5.39173766e-02],
#        [  2.74702281e-03,   8.27428385e-01,  -5.70810854e-02,
#          -4.13201239e-02,   1.82814373e-02,   2.29983506e-02,
#          -2.84164369e-02,  -1.83425411e-02,   2.88598376e-02,
#          -1.92653108e-02,   9.44672983e-03,  -5.45195182e-01,
#           3.09881180e-02,   2.75249953e-02,   2.84509495e-03,
#          -1.60927688e-02,  -1.29251892e-02,  -8.07565612e-02,
#          -3.41937934e-02,   2.84809473e-03],
#        [  8.22178230e-03,  -9.69664293e-02,  -3.62242298e-02,
#           1.49686240e-02,  -9.60064319e-03,  -3.31611713e-02,
#          -1.90164430e-01,  -1.85341971e-01,  -4.22739697e-01,
#           7.37008100e-03,   3.10005847e-03,  -2.45207113e-02,
#          -5.89626616e-02,   6.82451404e-02,   7.18003692e-03,
#           4.21646547e-02,  -3.85090955e-02,  -8.50231327e-01,
#          -3.35258707e-02,   4.94971883e-02],
#        [  8.94131978e-01,   1.86118935e-02,  -6.20642769e-03,
#          -2.86110639e-02,   1.85040552e-01,   1.36189464e-02,
#           4.01511674e-02,   1.99989559e-02,  -2.10565937e-01,
#           6.90991895e-04,   1.65457982e-02,   1.59678770e-02,
#           2.14998594e-02,   3.29761622e-02,   3.24047499e-01,
#           6.27449112e-04,   2.65792319e-02,   9.59564753e-02,
#           3.92575594e-02,   2.75724543e-03],
#        [  2.61880477e-01,   4.20566609e-02,  -1.13057887e-02,
#           2.01965185e-02,  -9.47061880e-01,  -1.89094830e-03,
#           3.12403374e-03,  -3.79006568e-04,   1.81215385e-02,
#          -1.38881577e-02,  -1.84065397e-02,   3.32640814e-02,
#          -2.74818392e-04,   4.48771065e-03,  -1.70840083e-01,
#           9.29491588e-03,  -2.82807190e-02,  -7.15955940e-04,
#           8.55240658e-03,   6.44046160e-03],
#        [ -2.96090613e-01,   1.52986376e-02,  -3.57309542e-03,
#           1.10058290e-03,  -2.47236536e-01,   2.98961101e-03,
#           1.25302324e-02,   6.81633009e-03,  -3.85026623e-02,
#          -4.47167385e-03,   9.13739522e-06,   1.25795297e-02,
#           2.39825071e-03,   8.67423165e-03,   9.21088497e-01,
#           4.38312919e-03,  -1.93341824e-03,   2.10018621e-02,
#           1.13257179e-02,   2.44965973e-03]])

# %%
plt.figure(figsize=(20,6))

X = np.arange(1,21)
cumulative_explained_variance_uci = np.cumsum(pca.explained_variance_ratio_)

plt.plot(X, cumulative_explained_variance_uci, '-o')
plt.bar(X, pca.explained_variance_ratio_, align='center', alpha=0.5)

for i, j in zip(X, np.cumsum(pca.explained_variance_ratio_)):
    plt.annotate(str(j.round(4)), xy=(i+.2,j-.02))
    
plt.xlabel('PCA components')
plt.ylabel('Explained variance')

# %%
X_pca = pca.transform(imp_feat_df)

# %%
X_pca.shape, y_10pct_1.shape
# Out:
# ((2000, 20), (2000,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca,
                                                    y,
                                                    test_size = .3,
                                                    )

# %% [markdown]
# ## Implementing Final Model with KNN

# %%
knn_pipe = Pipeline([
    ('knn', KNeighborsClassifier())
])

# %%
knn_params = {
    'knn__n_neighbors': range(1,10,2)
}

# %%
knn_gs = GridSearchCV(knn_pipe, param_grid=knn_params, cv=5, n_jobs=-1, verbose=1)

# %%
knn_gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    0.5s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Pipeline(steps=[('knn', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'))]),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'knn__n_neighbors': range(1, 10, 2)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=1)

# %% [markdown]
# ### KNN Scores

# %%
pd.DataFrame(knn_gs.cv_results_).sort_values(by='rank_test_score').T
# Out:
#                                               2                        3  \
# mean_fit_time                          0.001899               0.00193162
# mean_score_time                      0.00418243               0.00460124
# mean_test_score                        0.877857                 0.869286
# mean_train_score                       0.916071                 0.910002
# param_knn__n_neighbors                        5                        7
# params                  {'knn__n_neighbors': 5}  {'knn__n_neighbors': 7}
# rank_test_score                               1                        2
# split0_test_score                       0.88968                  0.88968
# split0_train_score                     0.914209                 0.913315
# split1_test_score                      0.868327                 0.854093
# split1_train_score                      0.91689                 0.911528
# split2_test_score                      0.889286                 0.871429
# split2_train_score                     0.916964                   0.9125
# split3_test_score                      0.903226                 0.896057
# split3_train_score                     0.914362                 0.902765
# split4_test_score                       0.83871                 0.835125
# split4_train_score                      0.91793                 0.909902
# std_fit_time                        4.89944e-05              4.40793e-05
# std_score_time                      0.000157405              0.000133401
# std_test_score                         0.022496                 0.022497
# std_train_score                      0.00150419                0.0037928
#
#                                               4                        1  \
# mean_fit_time                        0.00190897               0.00193424
# mean_score_time                      0.00493126               0.00377712
# mean_test_score                        0.868571                 0.867857
# mean_train_score                       0.899818                 0.933749
# param_knn__n_neighbors                        9                        3
# params                  {'knn__n_neighbors': 9}  {'knn__n_neighbors': 3}
# rank_test_score                               3                        4
# split0_test_score                      0.875445                  0.88968
# split0_train_score                     0.900804                 0.927614
# split1_test_score                      0.868327                 0.850534
# split1_train_score                     0.887399                 0.939231
# split2_test_score                      0.867857                 0.882143
# split2_train_score                     0.901786                  0.93125
# split3_test_score                      0.888889                 0.878136
# split3_train_score                     0.898305                 0.935772
# split4_test_score                      0.842294                  0.83871
# split4_train_score                     0.910794                  0.93488
# std_fit_time                        4.85912e-05              0.000195599
# std_score_time                      0.000128661               0.00012218
# std_test_score                        0.0151483                0.0196723
# std_train_score                      0.00750766               0.00398273
#
#                                               0
# mean_fit_time                        0.00195966
# mean_score_time                        0.003157
# mean_test_score                        0.855714
# mean_train_score                              1
# param_knn__n_neighbors                        1
# params                  {'knn__n_neighbors': 1}
# rank_test_score                               5
# split0_test_score                      0.875445
# split0_train_score                            1
# split1_test_score                       0.83274
# split1_train_score                            1
# split2_test_score                      0.864286
# split2_train_score                            1
# split3_test_score                      0.892473
# split3_train_score                            1
# split4_test_score                       0.81362
# split4_train_score                            1
# std_fit_time                        0.000228346
# std_score_time                      7.91938e-05
# std_test_score                         0.028656
# std_train_score                               0

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knn.score(X_test, y_test)
# Out:
# 0.8716666666666667

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#          -1       0.84      0.91      0.87       292
#           1       0.91      0.83      0.87       308
#
# avg / total       0.87      0.87      0.87       600

# %% [markdown]
# ## Implementing Final Model with DECISION TREE CLASSIFIER

# %%
dtc_pipe =  Pipeline([
    ('dtc', DecisionTreeClassifier())
])

# %%
dtc_parms = {
    'dtc__max_depth': [3,7,11,None],
    'dtc__max_features': [3,5,7,None]
}

# %%
dtc_gs = GridSearchCV(dtc_pipe, dtc_parms, cv = 5, verbose = 1, n_jobs = -1)

# %%
dtc_gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    0.8s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Pipeline(steps=[('dtc', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'))]),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'dtc__max_depth': [3, 7, 11, None], 'dtc__max_features': [3, 5, 7, None]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=1)

# %% [markdown]
# ### Decision Tree Scores

# %%
pd.DataFrame(dtc_gs.cv_results_).sort_values(by='rank_test_score').T
# Out:
#                                                                        7   \
# mean_fit_time                                                    0.015314
# mean_score_time                                               0.000351715
# mean_test_score                                                      0.73
# mean_train_score                                                 0.886069
# param_dtc__max_depth                                                    7
# param_dtc__max_features                                              None
# params                   {'dtc__max_depth': 7, 'dtc__max_features': None}
# rank_test_score                                                         1
# split0_test_score                                                0.772242
# split0_train_score                                               0.874888
# split1_test_score                                                0.686833
# split1_train_score                                               0.887399
# split2_test_score                                                0.728571
# split2_train_score                                               0.891964
# split3_test_score                                                0.698925
# split3_train_score                                               0.881356
# split4_test_score                                                0.763441
# split4_train_score                                               0.894737
# std_fit_time                                                  0.000208627
# std_score_time                                                2.62024e-05
# std_test_score                                                  0.0338803
# std_train_score                                                0.00719552
#
#                                                                     6   \
# mean_fit_time                                               0.00707884
# mean_score_time                                            0.000347519
# mean_test_score                                               0.719286
# mean_train_score                                               0.85965
# param_dtc__max_depth                                                 7
# param_dtc__max_features                                              7
# params                   {'dtc__max_depth': 7, 'dtc__max_features': 7}
# rank_test_score                                                      2
# split0_test_score                                             0.758007
# split0_train_score                                            0.881144
# split1_test_score                                             0.729537
# split1_train_score                                            0.861483
# split2_test_score                                             0.696429
# split2_train_score                                            0.855357
# split3_test_score                                             0.727599
# split3_train_score                                            0.865299
# split4_test_score                                             0.684588
# split4_train_score                                            0.834969
# std_fit_time                                                0.00116728
# std_score_time                                              1.5207e-05
# std_test_score                                               0.0260811
# std_train_score                                               0.014999
#
#                                                                         15  \
# mean_fit_time                                                     0.019412
# mean_score_time                                                0.000449085
# mean_test_score                                                   0.715714
# mean_train_score                                                         1
# param_dtc__max_depth                                                  None
# param_dtc__max_features                                               None
# params                   {'dtc__max_depth': None, 'dtc__max_features': ...
# rank_test_score                                                          3
# split0_test_score                                                 0.725979
# split0_train_score                                                       1
# split1_test_score                                                  0.66548
# split1_train_score                                                       1
# split2_test_score                                                 0.717857
# split2_train_score                                                       1
# split3_test_score                                                 0.706093
# split3_train_score                                                       1
# split4_test_score                                                 0.763441
# split4_train_score                                                       1
# std_fit_time                                                   0.000804273
# std_score_time                                                 3.40188e-05
# std_test_score                                                   0.0316376
# std_train_score                                                          0
#
#                                                                         11  \
# mean_fit_time                                                    0.0188106
# mean_score_time                                                0.000444984
# mean_test_score                                                   0.712857
# mean_train_score                                                  0.981963
# param_dtc__max_depth                                                    11
# param_dtc__max_features                                               None
# params                   {'dtc__max_depth': 11, 'dtc__max_features': None}
# rank_test_score                                                          4
# split0_test_score                                                 0.740214
# split0_train_score                                                0.982127
# split1_test_score                                                  0.69395
# split1_train_score                                                0.974084
# split2_test_score                                                 0.710714
# split2_train_score                                                0.989286
# split3_test_score                                                 0.691756
# split3_train_score                                                0.978591
# split4_test_score                                                 0.727599
# split4_train_score                                                0.985727
# std_fit_time                                                   0.000605817
# std_score_time                                                 4.30689e-05
# std_test_score                                                   0.0188392
# std_train_score                                                 0.00531543
#
#                                                                      9   \
# mean_fit_time                                                0.00615854
# mean_score_time                                             0.000384474
# mean_test_score                                                0.681429
# mean_train_score                                               0.930344
# param_dtc__max_depth                                                 11
# param_dtc__max_features                                               5
# params                   {'dtc__max_depth': 11, 'dtc__max_features': 5}
# rank_test_score                                                       5
# split0_test_score                                              0.690391
# split0_train_score                                             0.857015
# split1_test_score                                              0.708185
# split1_train_score                                             0.958892
# split2_test_score                                              0.646429
# split2_train_score                                              0.94375
# split3_test_score                                              0.684588
# split3_train_score                                             0.945584
# split4_test_score                                              0.677419
# split4_train_score                                             0.946476
# std_fit_time                                                0.000154827
# std_score_time                                              9.86903e-06
# std_test_score                                                0.0202487
# std_train_score                                               0.0370522
#
#                                                                        14  \
# mean_fit_time                                                  0.00822697
# mean_score_time                                                0.00037632
# mean_test_score                                                  0.669286
# mean_train_score                                                        1
# param_dtc__max_depth                                                 None
# param_dtc__max_features                                                 7
# params                   {'dtc__max_depth': None, 'dtc__max_features': 7}
# rank_test_score                                                         6
# split0_test_score                                                0.651246
# split0_train_score                                                      1
# split1_test_score                                                0.679715
# split1_train_score                                                      1
# split2_test_score                                                0.714286
# split2_train_score                                                      1
# split3_test_score                                                0.663082
# split3_train_score                                                      1
# split4_test_score                                                0.637993
# split4_train_score                                                      1
# std_fit_time                                                  0.000408597
# std_score_time                                                2.64194e-05
# std_test_score                                                  0.0263623
# std_train_score                                                         0
#
#                                                                        3   \
# mean_fit_time                                                  0.00822968
# mean_score_time                                                0.00034852
# mean_test_score                                                  0.662857
# mean_train_score                                                 0.703752
# param_dtc__max_depth                                                    3
# param_dtc__max_features                                              None
# params                   {'dtc__max_depth': 3, 'dtc__max_features': None}
# rank_test_score                                                         7
# split0_test_score                                                0.679715
# split0_train_score                                               0.705987
# split1_test_score                                                0.647687
# split1_train_score                                               0.703307
# split2_test_score                                                0.664286
# split2_train_score                                               0.710714
# split3_test_score                                                0.620072
# split3_train_score                                               0.684211
# split4_test_score                                                0.702509
# split4_train_score                                               0.714541
# std_fit_time                                                  0.000139835
# std_score_time                                                 8.0505e-06
# std_test_score                                                  0.0279604
# std_train_score                                                 0.0105065
#
#                                                                      10  \
# mean_fit_time                                                0.00785418
# mean_score_time                                             0.000366449
# mean_test_score                                                    0.66
# mean_train_score                                               0.954653
# param_dtc__max_depth                                                 11
# param_dtc__max_features                                               7
# params                   {'dtc__max_depth': 11, 'dtc__max_features': 7}
# rank_test_score                                                       8
# split0_test_score                                              0.708185
# split0_train_score                                             0.965147
# split1_test_score                                              0.672598
# split1_train_score                                              0.97319
# split2_test_score                                              0.653571
# split2_train_score                                             0.952679
# split3_test_score                                              0.620072
# split3_train_score                                             0.929527
# split4_test_score                                              0.645161
# split4_train_score                                             0.952721
# std_fit_time                                                0.000105781
# std_score_time                                              2.08471e-05
# std_test_score                                                0.0294573
# std_train_score                                               0.0147831
#
#                                                                     5   \
# mean_fit_time                                               0.00509887
# mean_score_time                                            0.000367546
# mean_test_score                                               0.646429
# mean_train_score                                              0.799826
# param_dtc__max_depth                                                 7
# param_dtc__max_features                                              5
# params                   {'dtc__max_depth': 7, 'dtc__max_features': 5}
# rank_test_score                                                      9
# split0_test_score                                             0.658363
# split0_train_score                                            0.758713
# split1_test_score                                             0.704626
# split1_train_score                                             0.84361
# split2_test_score                                             0.628571
# split2_train_score                                            0.819643
# split3_test_score                                             0.537634
# split3_train_score                                            0.752007
# split4_test_score                                             0.702509
# split4_train_score                                            0.825156
# std_fit_time                                               0.000105021
# std_score_time                                             9.32287e-06
# std_test_score                                               0.0613002
# std_train_score                                              0.0372245
#
#                                                                        13  \
# mean_fit_time                                                  0.00679207
# mean_score_time                                               0.000385809
# mean_test_score                                                  0.645714
# mean_train_score                                                        1
# param_dtc__max_depth                                                 None
# param_dtc__max_features                                                 5
# params                   {'dtc__max_depth': None, 'dtc__max_features': 5}
# rank_test_score                                                        10
# split0_test_score                                                0.676157
# split0_train_score                                                      1
# split1_test_score                                                0.658363
# split1_train_score                                                      1
# split2_test_score                                                0.678571
# split2_train_score                                                      1
# split3_test_score                                                0.641577
# split3_train_score                                                      1
# split4_test_score                                                0.573477
# split4_train_score                                                      1
# std_fit_time                                                  0.000415805
# std_score_time                                                2.75806e-05
# std_test_score                                                  0.0384367
# std_train_score                                                         0
#
#                                                                     2   \
# mean_fit_time                                               0.00378804
# mean_score_time                                            0.000340271
# mean_test_score                                               0.637857
# mean_train_score                                              0.662317
# param_dtc__max_depth                                                 3
# param_dtc__max_features                                              7
# params                   {'dtc__max_depth': 3, 'dtc__max_features': 7}
# rank_test_score                                                     11
# split0_test_score                                             0.679715
# split0_train_score                                             0.69437
# split1_test_score                                             0.615658
# split1_train_score                                            0.607685
# split2_test_score                                             0.682143
# split2_train_score                                             0.68125
# split3_test_score                                             0.620072
# split3_train_score                                            0.669045
# split4_test_score                                             0.591398
# split4_train_score                                            0.659233
# std_fit_time                                               3.24542e-05
# std_score_time                                              1.7116e-05
# std_test_score                                               0.0365516
# std_train_score                                              0.0297498
#
#                                                                        12  \
# mean_fit_time                                                  0.00543909
# mean_score_time                                               0.000385714
# mean_test_score                                                  0.610714
# mean_train_score                                                        1
# param_dtc__max_depth                                                 None
# param_dtc__max_features                                                 3
# params                   {'dtc__max_depth': None, 'dtc__max_features': 3}
# rank_test_score                                                        12
# split0_test_score                                                0.619217
# split0_train_score                                                      1
# split1_test_score                                                 0.58363
# split1_train_score                                                      1
# split2_test_score                                                0.607143
# split2_train_score                                                      1
# split3_test_score                                                0.591398
# split3_train_score                                                      1
# split4_test_score                                                 0.65233
# split4_train_score                                                      1
# std_fit_time                                                  0.000451737
# std_score_time                                                1.35033e-05
# std_test_score                                                  0.0241617
# std_train_score                                                         0
#
#                                                                     4   \
# mean_fit_time                                               0.00367742
# mean_score_time                                            0.000371122
# mean_test_score                                               0.607857
# mean_train_score                                              0.740728
# param_dtc__max_depth                                                 7
# param_dtc__max_features                                              3
# params                   {'dtc__max_depth': 7, 'dtc__max_features': 3}
# rank_test_score                                                     13
# split0_test_score                                             0.679715
# split0_train_score                                            0.790885
# split1_test_score                                             0.569395
# split1_train_score                                            0.730116
# split2_test_score                                             0.592857
# split2_train_score                                            0.738393
# split3_test_score                                             0.548387
# split3_train_score                                            0.692239
# split4_test_score                                             0.648746
# split4_train_score                                            0.752007
# std_fit_time                                               4.24107e-05
# std_score_time                                             1.29429e-05
# std_test_score                                               0.0491561
# std_train_score                                              0.0319755
#
#                                                                      8   \
# mean_fit_time                                                0.00461316
# mean_score_time                                             0.000375175
# mean_test_score                                                0.595714
# mean_train_score                                               0.879456
# param_dtc__max_depth                                                 11
# param_dtc__max_features                                               3
# params                   {'dtc__max_depth': 11, 'dtc__max_features': 3}
# rank_test_score                                                      14
# split0_test_score                                              0.608541
# split0_train_score                                             0.873101
# split1_test_score                                              0.572954
# split1_train_score                                             0.852547
# split2_test_score                                              0.553571
# split2_train_score                                             0.898214
# split3_test_score                                               0.62724
# split3_train_score                                              0.91347
# split4_test_score                                              0.616487
# split4_train_score                                             0.859946
# std_fit_time                                                6.00351e-05
# std_score_time                                               2.0807e-05
# std_test_score                                                0.0278616
# std_train_score                                               0.0230388
#
#                                                                     1   \
# mean_fit_time                                               0.00315003
# mean_score_time                                            0.000338745
# mean_test_score                                                  0.575
# mean_train_score                                              0.596758
# param_dtc__max_depth                                                 3
# param_dtc__max_features                                              5
# params                   {'dtc__max_depth': 3, 'dtc__max_features': 5}
# rank_test_score                                                     15
# split0_test_score                                             0.501779
# split0_train_score                                            0.550492
# split1_test_score                                             0.491103
# split1_train_score                                            0.551385
# split2_test_score                                             0.660714
# split2_train_score                                               0.625
# split3_test_score                                             0.598566
# split3_train_score                                            0.612846
# split4_test_score                                             0.623656
# split4_train_score                                            0.644068
# std_fit_time                                               4.86146e-05
# std_score_time                                             1.70688e-05
# std_test_score                                               0.0673847
# std_train_score                                              0.0387141
#
#                                                                     0
# mean_fit_time                                               0.00252738
# mean_score_time                                             0.00036087
# mean_test_score                                               0.562143
# mean_train_score                                              0.604839
# param_dtc__max_depth                                                 3
# param_dtc__max_features                                              3
# params                   {'dtc__max_depth': 3, 'dtc__max_features': 3}
# rank_test_score                                                     16
# split0_test_score                                             0.615658
# split0_train_score                                            0.633601
# split1_test_score                                             0.565836
# split1_train_score                                            0.646113
# split2_test_score                                             0.503571
# split2_train_score                                            0.561607
# split3_test_score                                             0.516129
# split3_train_score                                            0.528992
# split4_test_score                                             0.609319
# split4_train_score                                             0.65388
# std_fit_time                                               0.000119571
# std_score_time                                             2.47159e-05
# std_test_score                                               0.0461428
# std_train_score                                              0.0501151

# %%
dtc_clf = DecisionTreeClassifier(max_depth=7, max_features=None)

# %%
dtc_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=7,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
dtc_clf.score(X_test, y_test)
# Out:
# 0.72999999999999998

# %%
y_pred_dtc = dtc_clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred_dtc))
# Out:
#              precision    recall  f1-score   support
#
#          -1       0.72      0.72      0.72       292
#           1       0.74      0.74      0.74       308
#
# avg / total       0.73      0.73      0.73       600

# %% [markdown]
# # Implementing Final Model with LOGISTIC REGRESSION

# %%
simple_pipe_1 = Pipeline([
    ('lnr',  LogisticRegression())
])

# %%
simple_param_1 = {
    'lnr__C': [10,25,50,75,100]
}

# %%
simple2_gs = GridSearchCV(simple_pipe_1, param_grid=simple_param_1, cv=5, n_jobs=-1, verbose=1)

# %%
simple2_gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    0.4s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Pipeline(steps=[('lnr', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))]),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'lnr__C': [10, 25, 50, 75, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=1)

# %%
pd.DataFrame(simple2_gs.cv_results_).sort_values(by='rank_test_score').T
# Out:
#                                  0               1               2  \
# mean_fit_time            0.0118229       0.0110405       0.0119557
# mean_score_time        0.000363398     0.000351048     0.000360537
# mean_test_score           0.590714        0.590714        0.590714
# mean_train_score          0.608927        0.608748        0.608748
# param_lnr__C                    10              25              50
# params              {'lnr__C': 10}  {'lnr__C': 25}  {'lnr__C': 50}
# rank_test_score                  1               1               1
# split0_test_score         0.640569        0.640569        0.640569
# split0_train_score        0.600536        0.600536        0.600536
# split1_test_score         0.565836        0.565836        0.565836
# split1_train_score        0.621984        0.621984        0.621984
# split2_test_score         0.642857        0.642857        0.642857
# split2_train_score        0.588393        0.588393        0.588393
# split3_test_score         0.530466        0.530466        0.530466
# split3_train_score         0.62355         0.62355         0.62355
# split4_test_score         0.573477        0.573477        0.573477
# split4_train_score        0.610169        0.609277        0.609277
# std_fit_time            0.00102895      0.00128648      0.00144551
# std_score_time         2.65618e-05     8.71269e-06     1.79613e-05
# std_test_score           0.0441529       0.0441529       0.0441529
# std_train_score          0.0132509       0.0132389       0.0132389
#
#                                  3                4
# mean_fit_time             0.011587        0.0113633
# mean_score_time        0.000343084      0.000346422
# mean_test_score           0.590714         0.590714
# mean_train_score          0.608748         0.609105
# param_lnr__C                    75              100
# params              {'lnr__C': 75}  {'lnr__C': 100}
# rank_test_score                  1                1
# split0_test_score         0.640569         0.640569
# split0_train_score        0.600536         0.600536
# split1_test_score         0.565836         0.565836
# split1_train_score        0.621984         0.621984
# split2_test_score         0.642857         0.642857
# split2_train_score        0.588393         0.588393
# split3_test_score         0.530466         0.530466
# split3_train_score         0.62355          0.62355
# split4_test_score         0.573477         0.573477
# split4_train_score        0.609277         0.611062
# std_fit_time           0.000977981      0.000678265
# std_score_time         1.24645e-05      6.94776e-06
# std_test_score           0.0441529        0.0441529
# std_train_score          0.0132389        0.0132724

# %%
simple2_gs.score(X_test, y_test)
# Out:
# 0.6166666666666667

# %% [markdown]
# ## The highest average score of 0.87 was acheived using KNN
